# %% [markdown]
# #Airbnb: Where will a new guest book their first travel experience?

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import dateutil.parser

# %%
#Read in data from folder with csv files
train_users = pd.read_csv("train_users_2.csv")  #this is the fixed data from kaggle (last 15 usrs had mistakes)
#age_gender_bkts = pd.read_csv("age_gender_bkts.csv")
#sessions = pd.read_csv("sessions.csv")
#countries = pd.read_csv("countries.csv")
test_users = pd.read_csv("test_users.csv")

# %% [markdown]
# After looking through the files, it seems that most relevant features are represented within the training data set. There may be potential new features we can derive from the countries* file but for sake of simplicity, we will work with just the training and test sets
#
#
# *specifically levenshtein distance (edit distance)

# %%
print train_users.dtypes
print 
print test_users.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object
#
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking         float64
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# dtype: object

# %% [markdown]
# **Objectives**
#
# We're predicting **country_destination** for every **test user**.
#
# Need a list of countries
#
# So drop country_destination from train to use as labels. This equalizes the column names of the training and test set.
#
# We will also need of all the ID's of the test users.

# %%
country_dests = train_users.country_destination.values #Labels

train_users = train_users.drop(['country_destination'],axis=1) 
test_ids = test_users.id #series of test ids

train_users.shape
# Out:
# (213451, 15)

# %%
#for retrieving training set
total_train_users = train_users.shape[0]

print "Train User Count:", total_train_users
print "Test User Count:", test_users.shape[0]
print train_users.dtypes
# Out:
# Train User Count: 213451
# Test User Count: 62096
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# dtype: object

# %% [markdown]
# As a note, it looks like there are date variables that are not date types.
#
# Before we do any manipulation of data, we're going to concatenate the test and training data. This way any features created in the training set will be reflected in the test set.

# %%
#Concatenating train and test data by rows
full_df = pd.concat((train_users, test_users), axis=0, ignore_index=True)

# %%
full_df.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender  age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-  NaN      facebook            0       en            direct
# 1       MALE   38      facebook            0       en               seo
# 2     FEMALE   56         basic            3       en            direct
# 3     FEMALE   42      facebook            0       en            direct
# 4  -unknown-   41         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser
# 0        Chrome
# 1        Chrome
# 2            IE
# 3       Firefox
# 4        Chrome

# %% [markdown]
# **Data Cleaning**
#
# Preprocessing of the data:
#     - drop irrelevant columns
#       (note: kaggle has removed 'date_first_booking' var)
#     - deal with missing values
#     - convert date values

# %%
#drop id an date_first_booking columns
full_df_processed = full_df.drop(['id', 'date_first_booking'], axis=1)

#fill in missing values nans
full_df_processed = full_df_processed.fillna(np.nan)

# %%
full_df_processed
# Out:
#        date_account_created  timestamp_first_active     gender  age  \
# 0                2010-06-28          20090319043255  -unknown-  NaN
# 1                2011-05-25          20090523174809       MALE   38
# 2                2010-09-28          20090609231247     FEMALE   56
# 3                2011-12-05          20091031060129     FEMALE   42
# 4                2010-09-14          20091208061105  -unknown-   41
# 5                2010-01-01          20100101215619  -unknown-  NaN
# 6                2010-01-02          20100102012558     FEMALE   46
# 7                2010-01-03          20100103191905     FEMALE   47
# 8                2010-01-04          20100104004211     FEMALE   50
# 9                2010-01-04          20100104023758  -unknown-   46
# 10               2010-01-04          20100104194251     FEMALE   36
# 11               2010-01-05          20100105051812     FEMALE   47
# 12               2010-01-05          20100105060859  -unknown-  NaN
# 13               2010-01-05          20100105083259     FEMALE   37
# 14               2010-01-07          20100107055820     FEMALE   36
# 15               2010-01-07          20100107204555     FEMALE   33
# 16               2010-01-07          20100107215125  -unknown-  NaN
# 17               2010-01-07          20100107224625  -unknown-   31
# 18               2010-01-08          20100108015641  -unknown-  NaN
# 19               2010-01-10          20100110010817     FEMALE   29
# 20               2010-01-10          20100110152120  -unknown-  NaN
# 21               2010-01-10          20100110220941       MALE   30
# 22               2010-01-11          20100111031438  -unknown-   40
# 23               2010-01-11          20100111224015  -unknown-  NaN
# 24               2010-01-11          20100111230808     FEMALE   40
# 25               2010-01-12          20100112131444     FEMALE   26
# 26               2010-01-12          20100112155420  -unknown-  NaN
# 27               2010-01-12          20100112205949     FEMALE   32
# 28               2010-01-13          20100113044650  -unknown-   35
# 29               2010-01-13          20100113064333  -unknown-   37
# ...                     ...                     ...        ...  ...
# 275517           2014-09-30          20140930231454  -unknown-  NaN
# 275518           2014-09-30          20140930231518     FEMALE   48
# 275519           2014-09-30          20140930231952  -unknown-  NaN
# 275520           2014-09-30          20140930232126     FEMALE   24
# 275521           2014-09-30          20140930232237     FEMALE   32
# 275522           2014-09-30          20140930232253  -unknown-  NaN
# 275523           2014-09-30          20140930232331  -unknown-  NaN
# 275524           2014-09-30          20140930232507  -unknown-  NaN
# 275525           2014-09-30          20140930232551  -unknown-  NaN
# 275526           2014-09-30          20140930232613     FEMALE   40
# 275527           2014-09-30          20140930233113       MALE   39
# 275528           2014-09-30          20140930233305  -unknown-  NaN
# 275529           2014-09-30          20140930233535  -unknown-  NaN
# 275530           2014-09-30          20140930233902       MALE   44
# 275531           2014-09-30          20140930234128  -unknown-   39
# 275532           2014-09-30          20140930234425     FEMALE   34
# 275533           2014-09-30          20140930234515  -unknown-  NaN
# 275534           2014-09-30          20140930234551       MALE   40
# 275535           2014-09-30          20140930234612       MALE   27
# 275536           2014-09-30          20140930234617     FEMALE   24
# 275537           2014-09-30          20140930234703  -unknown-  NaN
# 275538           2014-09-30          20140930234751       MALE   55
# 275539           2014-09-30          20140930234904  -unknown-   34
# 275540           2014-09-30          20140930235000       MALE   32
# 275541           2014-09-30          20140930235019  -unknown-  NaN
# 275542           2014-09-30          20140930235232  -unknown-   31
# 275543           2014-09-30          20140930235306  -unknown-  NaN
# 275544           2014-09-30          20140930235408  -unknown-  NaN
# 275545           2014-09-30          20140930235430  -unknown-  NaN
# 275546           2014-09-30          20140930235901     FEMALE   49
#
#        signup_method  signup_flow language affiliate_channel  \
# 0           facebook            0       en            direct
# 1           facebook            0       en               seo
# 2              basic            3       en            direct
# 3           facebook            0       en            direct
# 4              basic            0       en            direct
# 5              basic            0       en             other
# 6              basic            0       en             other
# 7              basic            0       en            direct
# 8              basic            0       en             other
# 9              basic            0       en             other
# 10             basic            0       en             other
# 11             basic            0       en             other
# 12             basic            0       en            direct
# 13             basic            0       en             other
# 14             basic            0       en             other
# 15             basic            0       en            direct
# 16             basic            0       en             other
# 17             basic            0       en             other
# 18             basic            0       en               seo
# 19             basic            0       en            direct
# 20             basic            0       en            direct
# 21             basic            0       en            direct
# 22             basic            0       en               seo
# 23             basic            0       en             other
# 24             basic            0       en               seo
# 25             basic            0       en             other
# 26             basic            0       en             other
# 27             basic            0       en             other
# 28             basic            0       en            direct
# 29             basic            0       en            direct
# ...              ...          ...      ...               ...
# 275517        google           12       en            direct
# 275518         basic            0       en            direct
# 275519         basic            0       en               seo
# 275520      facebook           25       en            direct
# 275521      facebook            0       en               seo
# 275522         basic            0       en            direct
# 275523         basic           23       en            direct
# 275524         basic           23       en            direct
# 275525         basic            0       en            direct
# 275526      facebook            0       en         sem-brand
# 275527      facebook            0       en               seo
# 275528         basic            0       en               seo
# 275529         basic            0       en               seo
# 275530         basic            0       en               seo
# 275531         basic            0       en               seo
# 275532      facebook           23       en            direct
# 275533         basic            0       en               seo
# 275534      facebook           23       en            direct
# 275535      facebook            0       en            direct
# 275536      facebook            0       en            direct
# 275537         basic           25       en            direct
# 275538         basic            0       en         sem-brand
# 275539         basic            0       en            direct
# 275540         basic            0       en            direct
# 275541         basic            0       en               seo
# 275542         basic            0       en            direct
# 275543         basic           23       ko            direct
# 275544         basic            0       de            direct
# 275545         basic            0       en         sem-brand
# 275546         basic            0       en             other
#
#        affiliate_provider first_affiliate_tracked signup_app  \
# 0                  direct               untracked        Web
# 1                  google               untracked        Web
# 2                  direct               untracked        Web
# 3                  direct               untracked        Web
# 4                  direct               untracked        Web
# 5                   other                     omg        Web
# 6              craigslist               untracked        Web
# 7                  direct                     omg        Web
# 8              craigslist               untracked        Web
# 9              craigslist                     omg        Web
# 10             craigslist               untracked        Web
# 11             craigslist               untracked        Web
# 12                 direct                     NaN        Web
# 13             craigslist                  linked        Web
# 14             craigslist               untracked        Web
# 15                 direct               untracked        Web
# 16             craigslist                     NaN        Web
# 17             craigslist                     NaN        Web
# 18               facebook                     NaN        Web
# 19                 direct               untracked        Web
# 20                 direct                     NaN        Web
# 21                 direct                  linked        Web
# 22                 google               untracked        Web
# 23             craigslist               untracked        Web
# 24                 google               untracked        Web
# 25             craigslist               untracked        Web
# 26                  other               untracked        Web
# 27             craigslist               untracked        Web
# 28                 direct                     NaN        Web
# 29                 direct               untracked        Web
# ...                   ...                     ...        ...
# 275517             direct               untracked    Android
# 275518             direct               untracked        Web
# 275519             google               untracked        Web
# 275520             direct               untracked        iOS
# 275521           facebook               untracked        Web
# 275522             direct               untracked      Moweb
# 275523             direct               untracked    Android
# 275524             direct               untracked    Android
# 275525             direct                  linked      Moweb
# 275526             google                     omg        Web
# 275527           facebook               untracked        Web
# 275528             google               untracked        Web
# 275529             google               untracked        Web
# 275530             google                  linked        Web
# 275531             google                  linked        Web
# 275532             direct               untracked    Android
# 275533             google               untracked        Web
# 275534             direct               untracked    Android
# 275535             direct               untracked        Web
# 275536             direct                  linked        Web
# 275537             direct               untracked        iOS
# 275538             google                     omg        Web
# 275539             direct               untracked        Web
# 275540             direct                  linked        Web
# 275541              yahoo                  linked        Web
# 275542             direct               untracked        Web
# 275543             direct               untracked    Android
# 275544             direct                  linked        Web
# 275545             google                     omg        Web
# 275546              other           tracked-other        Web
#
#        first_device_type  first_browser
# 0            Mac Desktop         Chrome
# 1            Mac Desktop         Chrome
# 2        Windows Desktop             IE
# 3            Mac Desktop        Firefox
# 4            Mac Desktop         Chrome
# 5            Mac Desktop         Chrome
# 6            Mac Desktop         Safari
# 7            Mac Desktop         Safari
# 8            Mac Desktop         Safari
# 9            Mac Desktop        Firefox
# 10           Mac Desktop        Firefox
# 11                iPhone      -unknown-
# 12         Other/Unknown      -unknown-
# 13           Mac Desktop        Firefox
# 14                iPhone  Mobile Safari
# 15       Windows Desktop         Chrome
# 16         Other/Unknown      -unknown-
# 17         Other/Unknown      -unknown-
# 18         Other/Unknown      -unknown-
# 19           Mac Desktop         Chrome
# 20         Other/Unknown      -unknown-
# 21           Mac Desktop         Chrome
# 22                iPhone      -unknown-
# 23           Mac Desktop         Safari
# 24           Mac Desktop        Firefox
# 25           Mac Desktop         Chrome
# 26         Other/Unknown      -unknown-
# 27       Desktop (Other)         Chrome
# 28         Other/Unknown      -unknown-
# 29        Android Tablet      -unknown-
# ...                  ...            ...
# 275517     Android Phone      -unknown-
# 275518       Mac Desktop         Safari
# 275519       Mac Desktop        Firefox
# 275520            iPhone      -unknown-
# 275521              iPad  Mobile Safari
# 275522     Android Phone  Chrome Mobile
# 275523     Android Phone      -unknown-
# 275524     Android Phone      -unknown-
# 275525            iPhone  Mobile Safari
# 275526   Windows Desktop        Firefox
# 275527            iPhone  Mobile Safari
# 275528       Mac Desktop        Firefox
# 275529              iPad  Mobile Safari
# 275530       Mac Desktop         Chrome
# 275531   Windows Desktop        Firefox
# 275532     Android Phone      -unknown-
# 275533       Mac Desktop         Safari
# 275534     Android Phone      -unknown-
# 275535       Mac Desktop        Firefox
# 275536            iPhone  Mobile Safari
# 275537            iPhone      -unknown-
# 275538   Windows Desktop        Firefox
# 275539       Mac Desktop         Chrome
# 275540   Windows Desktop         Chrome
# 275541   Windows Desktop         Chrome
# 275542   Windows Desktop             IE
# 275543     Android Phone      -unknown-
# 275544   Windows Desktop        Firefox
# 275545       Mac Desktop         Safari
# 275546   Windows Desktop         Chrome
#
# [275547 rows x 13 columns]

# %% [markdown]
# **Feature engineering**

# %%
#date_account_created
dac = np.vstack(full_df_processed.date_account_created.astype(str).apply(lambda x: list(map(int, x.split('-')))).values)
full_df_processed['dac_year'] = dac[:,0]
full_df_processed['dac_month'] = dac[:,1]
full_df_processed['dac_day'] = dac[:,2]
full_df_processed = full_df_processed.drop(['date_account_created'], axis=1)

#timestamp_first_active
tfa = np.vstack(full_df_processed.timestamp_first_active.astype(str).apply(lambda x: list(map(int, [x[:4],x[4:6],x[6:8],x[8:10],x[10:12],x[12:14]]))).values)
full_df_processed['tfa_year'] = tfa[:,0]
full_df_processed['tfa_month'] = tfa[:,1]
full_df_processed['tfa_day'] = tfa[:,2]
full_df_processed = full_df_processed.drop(['timestamp_first_active'], axis=1)

#Age
age_vals = full_df_processed.age.values
full_df_processed['age'] = np.where(np.logical_or(age_vals<14, age_vals>100), -1, age_vals)

# %% [markdown]
# Take all the categorical variables and one hot encode them to effectively expand the feature space for each value within a variable.

# %%
#One-hot-encoding for all the categorical variables, in pandas it is get_dummies
onehot_features = ['gender', 'signup_method', 'signup_flow', 'language', 'affiliate_channel', 'affiliate_provider', 'first_affiliate_tracked', 'signup_app', 'first_device_type', 'first_browser']
for features in onehot_features:
    dummy = pd.get_dummies(full_df_processed[features], prefix=features)
    full_df_processed = full_df_processed.drop([features], axis=1)
    full_df_processed = pd.concat((full_df_processed,dummy), axis=1)

# %% [markdown]
# After we're done with the feature engineering, we have to do a test train split so we can start modelling. Here we separate the test set from the train set.

# %%
from sklearn.preprocessing import LabelEncoder

#Split train test
X = full_df_processed.values[:total_train_users]
le = LabelEncoder()
y = le.fit_transform(country_dests)
X_test = full_df_processed.values[total_train_users:]

# %% [markdown]
# **Xtreme Gradient Boost**

# %%
from xgboost.sklearn import XGBClassifier

xgb_model = XGBClassifier(max_depth=6, learning_rate=0.3, n_estimators=25,
                    objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)

# %%
xgb_model.fit(X,y)
y_predict = xgb_model.predict_proba(X_test)

# %%
y_predict
# Out:
# array([[ 0.00252676,  0.00444019,  0.00386385, ...,  0.00188116,
#          0.23364688,  0.05033169],
#        [ 0.0012286 ,  0.00226559,  0.00220368, ...,  0.0011906 ,
#          0.08853392,  0.01908013],
#        [ 0.00184581,  0.00546608,  0.00260161, ...,  0.00166532,
#          0.13277271,  0.03304368],
#        ...,
#        [ 0.00220435,  0.00329122,  0.00479375, ...,  0.00137607,
#          0.12579976,  0.02081754],
#        [ 0.00243874,  0.0043099 ,  0.00308475, ...,  0.00183532,
#          0.11655024,  0.02565344],
#        [ 0.00355523,  0.01006219,  0.00372463, ...,  0.00232251,
#          0.45914522,  0.04351977]], dtype=float32)

# %% [markdown]
# For submission, we'll take the 5 most probable countries per user. The kaggle challenge is using a NDCG (normalized discounted cumulative gain) algorithm that ranks the most relevant the highest and "discounting the gain" for the following guesses (or results in search engines)

# %%
ids = []  #list of ids
country_list = []  #list of countries
for i in range(len(test_ids)):
    idx = test_ids[i]
    ids += [idx] * 5
    country_list += le.inverse_transform(np.argsort(y_predict[i])[::-1])[:5].tolist()

# %%
#This generates the actual submission file
airbnb_submission = pd.DataFrame(np.column_stack((ids, country_list)), columns=['id', 'country'])
airbnb_submission.to_csv('airbnb_sub.csv',index=False)

# %%
#train_users.ix[:,15]
fig, (axis1) = plt.subplots(1,1,figsize=(15,5))
sns.countplot(x = "gender", data = train_users, ax= axis1)
plt.show()

fig, (axis1) = plt.subplots(1,1,figsize=(15,5))
sns.countplot(x = "country_destination", data = train_users, ax= axis1)
plt.show()
    
fig, (axis1) = plt.subplots(1,1,figsize=(15,5))
sns.countplot(x = "signup_method", data = train_users, ax= axis1)
plt.show()

# %%
fig, (axis1) = plt.subplots(1,1,figsize=(60,5))
sns.countplot(x = "age", data = train_users, ax= axis1)
plt.show()

# %%
countries
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
# 5                  GB        54.633220        -3.432277    6883.6590
# 6                  IT        41.873990        12.564167    8636.6310
# 7                  NL        52.133057         5.295250    7524.3203
# 8                  PT        39.553444        -7.839319    7355.2534
# 9                  US        36.966427       -95.844030       0.0000
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0          7741220                   eng                           0.00
# 1          9984670                   eng                           0.00
# 2           357022                   deu                          72.61
# 3           505370                   spa                          92.25
# 4           643801                   fra                          92.06
# 5           243610                   eng                           0.00
# 6           301340                   ita                          89.40
# 7            41543                   nld                          63.22
# 8            92090                   por                          95.45
# 9          9826675                   eng                           0.00

# %%
train_users["first_device_type"].value_counts()
# Out:
# Mac Desktop           74890
# Windows Desktop       60048
# iPhone                12148
# iPad                  11451
# Other/Unknown          9938
# Android Phone           951
# Desktop (Other)         932
# Android Tablet          828
# SmartPhone (Other)       53
# dtype: int64

# %%
y = train_users["country_destination"]
X = train_users.drop("country_destination", axis = 1)

# %%
train_users.gender.replace('-unknown-',np.NaN).value_counts(dropna=False).plot(kind='bar', rot=0)
plt.xlabel('Gender')
sns.despine()
